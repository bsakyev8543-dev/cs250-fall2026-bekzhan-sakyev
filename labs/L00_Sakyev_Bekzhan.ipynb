# %% [markdown]
# <a href="https://colab.research.google.com/github/bsakyev8543-dev/cs250-fall2026-bekzhan-sakyev/blob/main/labs/L00_Sakyev_Bekzhan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Bekzhan Sakyev"
github_username = "bsakyev8543-dev"
course = "CS 250"

print("Student:", name)
print("GitHub:", github_username)
print("Course:", course)
print("Colab + GitHub setup complete!")
# Out:
# Student: Bekzhan Sakyev
# GitHub: bsakyev8543-dev
# Course: CS 250
# Colab + GitHub setup complete!

# %%
favorite_number = 7

print("My favorite number is:", favorite_number)
print("Twice my favorite number is:", favorite_number * 2)
# Out:
# My favorite number is: 7
# Twice my favorite number is: 14
