# %% [markdown]
# <a href="https://colab.research.google.com/github/bsakyev8543-dev/cs250-fall2026-bekzhan-sakyev/blob/main/labs/L01_Sakyev_Bekzhan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world! I am Bekzhan!")
# Out:
# Hello world! I am Bekzhan!

# %%
print("Welcome to CS 250!")
print("Snowboarding and tennis are my favorite sports!")
print("Ready to learn Python in Colab!")
# Out:
# Welcome to CS 250!
# Snowboarding and tennis are my favorite sports!
# Ready to learn Python in Colab!

# %%
print("Welcome to my program!")
# Out:
# Welcome to my program!

# %%
print("Course: CS 250")
print("Topic: Introduction to Programming")
print("Language: Python")
# Out:
# Course: CS 250
# Topic: Introduction to Programming
# Language: Python

# %%
print("************************")
print("WELCOME TO CS 250")
print("Programming starts here!")
print("************************")
# Out:
# ************************
# WELCOME TO CS 250
# Programming starts here!
# ************************

# %%
# Activity 4.1:
print('line 1') # what will this display? Write your answer before you run it
print('line 2') # It Will display line 1 first and line 2 cause code is reading from top to bottom
# Out:
# line 1
# line 2

# %%
# Activity 4.2:
print(2 + 3) # on this line is int calculation
print("2 + 3") # on this one is jusr str
# Out:
# 5
# 2 + 3

# %%
# Activity 4.3:
# print(Invisible message)
print("Visible message")
# Out:
# Visible message

# %%
# Exercise 5.1 - your corrected version
print("Welcome to CS 250!") # SyntaxError: invalid syntax. Perhaps you forgot a comma?
# Out:
# Welcome to CS 250!

# %%
# Exercise 5.2 - your corrected version
print(10 / 2) # ZeroDivisionError: division by zero
# Out:
# 5.0

# %%
# Exercise 5.3 - your corrected version
print("The result of 2 + 3 is:") # The result of 2 + 3 is: 6 Logic error.
print(2 + 3)
# Out:
# The result of 2 + 3 is:
# 5

# %%
# Digital Introduction Card
# This program displays my student bio card using simple print statements

print("========================================")
print("HELLO! I'M BEKZHAN")
print("Major: Computer Science / Software Engineering")
print("Why programming? I want to build cool software and automate things.")
print("Technology I use: Google Colab")
print("I'm ready to learn Python!")
print("========================================")

# Optional extension
# Project idea section

print("\n--- FUTURE PROJECT ---")
print("I would like to create a mobile app that tracks sports activities")
print("like tennis matches and snowboarding stats!")
print("----------------------")
# Out:
# ...
# HELLO! I'M BEKZHAN
# Major: Computer Science / Software Engineering
# Why programming? I want to build cool software and automate things.
# Technology I use: Google Colab
# I'm ready to learn Python!
# ...
#
# --- FUTURE PROJECT ---
# I would like to create a mobile app that tracks sports activities
# like tennis matches and snowboarding stats!
# ----------------------

# %%
# 1. What is the difference between a code cell and a Markdown cell?
# A code cell contains executable Python code, while a Markdown cell contains formatted text, instructions, and explanations.

# 2. What debugging step helped you most today?
# Reading the very last line of the error message to immediately identify the error type.

# 3. What is one thing you can now do in Python that you could not do before this lab?
# I can navigate Google Colab, use print() statements properly, and fix basic syntax/logic errors.
